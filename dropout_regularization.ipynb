# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrirangGodbole23/Classification_projects/blob/main/dropout_regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/sonar_dataset.csv", header=None)
# df.shape

# %%
df.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (208, 61)

# %%
df.isna().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df[60].value_counts() #binary classification
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
X = df.drop(60, axis="columns")
y = df[60]

# %%
y.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: 60, dtype: object

# %%
y = pd.get_dummies(y, drop_first=True)
y.sample(5)
# Out:
#      R
# 96   1
# 175  0
# 4    1
# 123  0
# 84   1

# %%
y.value_counts()
# Out:
# R
# 0    111
# 1     97
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
X_train.shape
# Out:
# (156, 60)

# %%
X_test.shape
# Out:
# (52, 60)

# %%
X_train
# Out:
#          0       1       2       3   ...      56      57      58      59
# 67   0.0368  0.0403  0.0317  0.0293  ...  0.0135  0.0067  0.0078  0.0068
# 14   0.0124  0.0433  0.0604  0.0449  ...  0.0114  0.0196  0.0147  0.0062
# 164  0.0163  0.0198  0.0202  0.0386  ...  0.0084  0.0108  0.0083  0.0033
# 179  0.0394  0.0420  0.0446  0.0551  ...  0.0101  0.0068  0.0053  0.0087
# 19   0.0126  0.0149  0.0641  0.1732  ...  0.0181  0.0094  0.0116  0.0063
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 137  0.0430  0.0902  0.0833  0.0813  ...  0.0027  0.0162  0.0059  0.0021
# 72   0.0208  0.0186  0.0131  0.0211  ...  0.0028  0.0019  0.0049  0.0023
# 140  0.0412  0.1135  0.0518  0.0232  ...  0.0095  0.0225  0.0098  0.0085
# 37   0.0333  0.0221  0.0270  0.0481  ...  0.0143  0.0132  0.0051  0.0041
#
# [156 rows x 60 columns]

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# model = keras.Sequential([
#                 keras.layers.Dense(60, input_dim = 60, activation="relu"),
#                 keras.layers.Dense(40, activation = 'relu'),
#                 keras.layers.Dense(20, activation = 'relu'),
#                 keras.layers.Dense(1, activation = 'relu'),          
# ])


# model.compile(
#     optimizer="adam",
#     loss = 'binary_crossentropy',
#     metrics = ['accuracy']
# )



# model.fit(X_train, y_train, epochs=50, batch_size = 8)

# %%
# loss: 0.2933 - accuracy: 0.8782 for epochs 10, batch_size = 8 and for neuron 60, 40, 20, 1
# Epoch 10/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2944 - accuracy: 0.8718
# for 
# model = keras.Sequential([
#                 keras.layers.Dense(60, input_dim = 60, activation="relu"),
#                 keras.layers.Dense(40, activation = 'relu'),
#                 keras.layers.Dense(20, activation = 'relu'),
#                 keras.layers.Dense(1, activation = 'relu'),          
# ])

# %%
# model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7625 - accuracy: 0.7692
# [2.762519598007202, 0.7692307829856873]

# %%
# lets make an dropout model
dropout_model = keras.Sequential([
                keras.layers.Dense(60, input_dim = 60, activation="relu"),
                keras.layers.Dropout(0.5),
                keras.layers.Dense(40, activation = 'relu'),
                keras.layers.Dropout(0.5),
                keras.layers.Dense(20, activation = 'relu'),
                keras.layers.Dropout(0.5),
                keras.layers.Dense(1, activation = 'sigmoid'),          
])


dropout_model.compile(
    optimizer="adam",
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)



dropout_model.fit(X_train, y_train, epochs=100, batch_size = 8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 3ms/step - loss: 0.7016 - accuracy: 0.4872
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.5641
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7423 - accuracy: 0.4231
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.5769
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.5897
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7034 - accuracy: 0.4872
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6820 - accuracy: 0.5962
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.7000 - accuracy: 0.4936
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.5833
# Epoch 10/100
# ...

# %%
dropout_model.evaluate(X_test, y_test)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f810a792950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4713 - accuracy: 0.7692
# [0.4713258743286133, 0.7692307829856873]

# %%
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3017 - accuracy: 0.8846
# <keras.callbacks.History at 0x7f810ccf3690>
